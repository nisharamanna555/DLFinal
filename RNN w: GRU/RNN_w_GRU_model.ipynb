# %%
# %%capture
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
import pickle
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras import layers
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('balanced_dataset.csv')
df.head()
# Out:
#    class                                              tweet
# 0      0                                       queer gaywad
# 1      0         alsarabsss hes beaner smh tell hes mexican
# 2      0  youre fucking gay blacklisted hoe holding tehg...
# 3      0  lmfaoooo hate black people theres black people...
# 4      0                              least im nigger lmfao

# %% [markdown]
# ## Split Data

# %%
features = df['tweet']
target = df['class']

X_train, X_val, Y_train, Y_val = train_test_split(features,
												target,
												test_size=0.2,
												random_state=22)
X_train.shape, X_val.shape

# make labels categorical
Y_train = to_categorical(Y_train, num_classes=3)
Y_val = to_categorical(Y_val, num_classes=3)

# %% [markdown]
# ## Tokenizer

# %%
with open('tokenizer.pkl', 'rb') as handle:
    token = pickle.load(handle)

# %%
# generating token embeddings
max_words = 5000
max_len = 100

X_train_seq = token.texts_to_sequences(X_train)
X_val_seq = token.texts_to_sequences(X_val)

X_train_padded = pad_sequences(X_train_seq, maxlen=max_len)
X_val_padded = pad_sequences(X_val_seq, maxlen=max_len)

# %% [markdown]
# ## Model

# %%
model = keras.models.Sequential([
	layers.Embedding(max_words, 32, input_length=max_len),

	# GRU layer
	layers.Bidirectional(layers.GRU(16)),

	layers.Dense(512, activation='relu', kernel_regularizer='l1'),
	layers.BatchNormalization(),
	layers.Dropout(0.3),
	layers.Dense(3, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# add a dummy input to build the model
model.build((None, max_len))

keras.utils.plot_model(
    model,
    show_shapes=True,
    show_dtype=True,
    show_layer_activations=True
)

# %%
lr = ReduceLROnPlateau(patience = 2,
					monitor = 'val_loss',
					factor = 0.5,
					verbose = 0)

# %%
# custom callback to calculate precision, recall, and F1-score
class MetricsCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        val_predictions = np.argmax(self.model.predict(X_val_padded), axis=1)
        val_true = np.argmax(Y_val, axis=1)

        precision = precision_score(val_true, val_predictions, average='weighted')
        recall = recall_score(val_true, val_predictions, average='weighted')
        f1 = f1_score(val_true, val_predictions, average='weighted')

        print(f" - val_precision: {precision:.4f} - val_recall: {recall:.4f} - val_f1_score: {f1:.4f}")
        logs.update({'val_precision': precision, 'val_recall': recall, 'val_f1_score': f1})

# %%
metrics_callback = MetricsCallback()

history = model.fit(X_train_padded, Y_train,
					validation_data=(X_val_padded, Y_val),
					epochs=50,
					verbose=1,
					batch_size=32,
					callbacks=[lr, metrics_callback])
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#  - val_precision: 0.7178 - val_recall: 0.5094 - val_f1_score: 0.4476
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.6259 - loss: 3.9003 - val_accuracy: 0.5094 - val_loss: 1.0126 - learning_rate: 0.0010 - val_precision: 0.7178 - val_recall: 0.5094 - val_f1_score: 0.4476
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  - val_precision: 0.8637 - val_recall: 0.8641 - val_f1_score: 0.8631
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9069 - loss: 0.3741 - val_accuracy: 0.8641 - val_loss: 0.4963 - learning_rate: 0.0010 - val_precision: 0.8637 - val_recall: 0.8641 - val_f1_score: 0.8631
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8278 - val_recall: 0.7934 - val_f1_score: 0.7894
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9371 - loss: 0.2706 - val_accuracy: 0.7934 - val_loss: 0.6316 - learning_rate: 0.0010 - val_precision: 0.8278 - val_recall: 0.7934 - val_f1_score: 0.7894
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8681 - val_recall: 0.8620 - val_f1_score: 0.8611
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - accuracy: 0.9485 - loss: 0.2239 - val_accuracy: 0.8620 - val_loss: 0.5095 - learning_rate: 0.0010 - val_precision: 0.8681 - val_recall: 0.8620 - val_f1_score: 0.8611
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8822 - val_recall: 0.8783 - val_f1_score: 0.8763
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9685 - loss: 0.1497 - val_accuracy: 0.8783 - val_loss: 0.4595 - learning_rate: 5.0000e-04 - val_precision: 0.8822 - val_recall: 0.8783 - val_f1_score: 0.8763
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8735 - val_recall: 0.8599 - val_f1_score: 0.8552
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9755 - loss: 0.1257 - val_accuracy: 0.8599 - val_loss: 0.6538 - learning_rate: 5.0000e-04 - val_precision: 0.8735 - val_recall: 0.8599 - val_f1_score: 0.8552
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8895 - val_recall: 0.8887 - val_f1_score: 0.8869
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9775 - loss: 0.1194 - val_accuracy: 0.8887 - val_loss: 0.4544 - learning_rate: 5.0000e-04 - val_precision: 0.8895 - val_recall: 0.8887 - val_f1_score: 0.8869
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8861 - val_recall: 0.8829 - val_f1_score: 0.8802
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9824 - loss: 0.1036 - val_accuracy: 0.8829 - val_loss: 0.5576 - learning_rate: 5.0000e-04 - val_precision: 0.8861 - val_recall: 0.8829 - val_f1_score: 0.8802
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  - val_precision: 0.8424 - val_recall: 0.8281 - val_f1_score: 0.8256
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9831 - loss: 0.0977 - val_accuracy: 0.8281 - val_loss: 0.6356 - learning_rate: 5.0000e-04 - val_precision: 0.8424 - val_recall: 0.8281 - val_f1_score: 0.8256
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8956 - val_recall: 0.8959 - val_f1_score: 0.8946
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.9874 - loss: 0.0805 - val_accuracy: 0.8959 - val_loss: 0.4732 - learning_rate: 2.5000e-04 - val_precision: 0.8956 - val_recall: 0.8959 - val_f1_score: 0.8946
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8710 - val_recall: 0.8632 - val_f1_score: 0.8603
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9874 - loss: 0.0777 - val_accuracy: 0.8632 - val_loss: 0.5895 - learning_rate: 2.5000e-04 - val_precision: 0.8710 - val_recall: 0.8632 - val_f1_score: 0.8603
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8876 - val_recall: 0.8867 - val_f1_score: 0.8852
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.9881 - loss: 0.0701 - val_accuracy: 0.8867 - val_loss: 0.4944 - learning_rate: 1.2500e-04 - val_precision: 0.8876 - val_recall: 0.8867 - val_f1_score: 0.8852
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  - val_precision: 0.8860 - val_recall: 0.8854 - val_f1_score: 0.8840
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9905 - loss: 0.0624 - val_accuracy: 0.8854 - val_loss: 0.4952 - learning_rate: 1.2500e-04 - val_precision: 0.8860 - val_recall: 0.8854 - val_f1_score: 0.8840
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8938 - val_recall: 0.8934 - val_f1_score: 0.8917
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9902 - loss: 0.0609 - val_accuracy: 0.8934 - val_loss: 0.4852 - learning_rate: 6.2500e-05 - val_precision: 0.8938 - val_recall: 0.8934 - val_f1_score: 0.8917
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8855 - val_recall: 0.8850 - val_f1_score: 0.8836
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9911 - loss: 0.0537 - val_accuracy: 0.8850 - val_loss: 0.4869 - learning_rate: 6.2500e-05 - val_precision: 0.8855 - val_recall: 0.8850 - val_f1_score: 0.8836
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8891 - val_recall: 0.8892 - val_f1_score: 0.8878
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.9929 - loss: 0.0540 - val_accuracy: 0.8892 - val_loss: 0.4777 - learning_rate: 3.1250e-05 - val_precision: 0.8891 - val_recall: 0.8892 - val_f1_score: 0.8878
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#  - val_precision: 0.8923 - val_recall: 0.8921 - val_f1_score: 0.8905
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9927 - loss: 0.0517 - val_accuracy: 0.8921 - val_loss: 0.4833 - learning_rate: 3.1250e-05 - val_precision: 0.8923 - val_recall: 0.8921 - val_f1_score: 0.8905
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8923 - val_recall: 0.8917 - val_f1_score: 0.8901
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9922 - loss: 0.0495 - val_accuracy: 0.8917 - val_loss: 0.4854 - learning_rate: 1.5625e-05 - val_precision: 0.8923 - val_recall: 0.8917 - val_f1_score: 0.8901
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8900 - val_recall: 0.8892 - val_f1_score: 0.8877
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.
- val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8906 - val_recall: 0.8896 - val_f1_score: 0.8880
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.9924 - loss: 0.0490 - val_accuracy: 0.8896 - val_loss: 0.4913 - learning_rate: 1.5259e-08 - val_precision: 0.8906 - val_recall: 0.8896 - val_f1_score: 0.8880
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8904 - val_recall: 0.8900 - val_f1_score: 0.8885
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9927 - loss: 0.0461 - val_accuracy: 0.8900 - val_loss: 0.4825 - learning_rate: 7.6294e-09 - val_precision: 0.8904 - val_recall: 0.8900 - val_f1_score: 0.8885
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#  - val_precision: 0.8932 - val_recall: 0.8925 - val_f1_score: 0.8909
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9942 - loss: 0.0436 - val_accuracy: 0.8925 - val_loss: 0.4854 - learning_rate: 7.6294e-09 - val_precision: 0.8932 - val_recall: 0.8925 - val_f1_score: 0.8909
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8929 - val_recall: 0.8921 - val_f1_score: 0.8905
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9912 - loss: 0.0504 - val_accuracy: 0.8921 - val_loss: 0.4866 - learning_rate: 3.8147e-09 - val_precision: 0.8929 - val_recall: 0.8921 - val_f1_score: 0.8905
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9917 - loss: 0.0482 - val_accuracy: 0.8908 - val_loss: 0.4879 - learning_rate: 3.8147e-09 - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9909 - loss: 0.0537 - val_accuracy: 0.8908 - val_loss: 0.4879 - learning_rate: 1.9073e-09 - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#  - val_precision: 0.8904 - val_recall: 0.8900 - val_f1_score: 0.8885
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9934 - loss: 0.0482 - val_accuracy: 0.8900 - val_loss: 0.4833 - learning_rate: 1.9073e-09 - val_precision: 0.8904 - val_recall: 0.8900 - val_f1_score: 0.8885
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8932 - val_recall: 0.8925 - val_f1_score: 0.8909
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9914 - loss: 0.0509 - val_accuracy: 0.8925 - val_loss: 0.4854 - learning_rate: 9.5367e-10 - val_precision: 0.8932 - val_recall: 0.8925 - val_f1_score: 0.8909
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
#  - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9927 - loss: 0.0497 - val_accuracy: 0.8908 - val_loss: 0.4898 - learning_rate: 9.5367e-10 - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8929 - val_recall: 0.8921 - val_f1_score: 0.8905
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9922 - loss: 0.0476 - val_accuracy: 0.8921 - val_loss: 0.4859 - learning_rate: 4.7684e-10 - val_precision: 0.8929 - val_recall: 0.8921 - val_f1_score: 0.8905
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.9927 - loss: 0.0486 - val_accuracy: 0.8908 - val_loss: 0.4885 - learning_rate: 4.7684e-10 - val_precision: 0.8917 - val_recall: 0.8908 - val_f1_score: 0.8892
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#  - val_precision: 0.8906 - val_recall: 0.8896 - val_f1_score: 0.8880
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9906 - loss: 0.0532 - val_accuracy: 0.8896 - val_loss: 0.4904 - learning_rate: 2.3842e-10 - val_precision: 0.8906 - val_recall: 0.8896 - val_f1_score: 0.8880

# %% [markdown]
# ## Visualize Model Results

# %%
history_df = pd.DataFrame(history.history)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# plot loss
history_df.loc[:, ['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend(['Training Loss', 'Validation Loss'])

# plot accuracy
history_df.loc[:, ['accuracy', 'val_accuracy']].plot(ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend(['Training Accuracy', 'Validation Accuracy'])

plt.tight_layout()
plt.show()

# %%
pred = model.predict(X_val_padded)
pred_class = np.argmax(pred, axis=1)

# plot the confusion matrix
Y_val_class = np.argmax(Y_val, axis=1)
conf_matrix = confusion_matrix(Y_val_class, pred_class)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Hate Speech', 'Offensive Language', 'No Hate and Offensive'],
            yticklabels=['Hate Speech', 'Offensive Language', 'No Hate and Offensive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %%
print("Classification Report:\n")
print(classification_report(Y_val_class, pred_class))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       900
#            1       0.90      0.78      0.83       691
#            2       0.91      0.90      0.90       800
#
#     accuracy                           0.89      2391
#    macro avg       0.89      0.88      0.88      2391
# weighted avg       0.89      0.89      0.89      2391

# %%
# look at the misclassified tweets

pred_df = pd.DataFrame(pred_class, columns=['pred_class'])
pred_df['actual_class'] = np.argmax(Y_val, axis=1)
pred_df['tweet'] = X_val.values

misclassified_tweets = pred_df[pred_df['pred_class'] != pred_df['actual_class']]
misclassified_tweets.head()
# Out:
#     pred_class  actual_class                                          tweet
# 11           0             1                             release nudes cunt
# 21           0             2      worried lady behind building talking crow
# 60           2             0                              washing coon hair
# 71           0             1  never trust nicca volunteers another man info
# 76           0             1                    niggas expect pull ask hoes

# %% [markdown]
# ## Save Model

# %%
model.save('rnn_w_GRU.keras')
