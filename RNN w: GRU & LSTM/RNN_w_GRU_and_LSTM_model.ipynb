# %%
# %%capture
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
import pickle
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras import layers
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# ## Dataset

# %%
df = pd.read_csv('balanced_dataset.csv')
df.head()
# Out:
#    class                                              tweet
# 0      0                                       queer gaywad
# 1      0         alsarabsss hes beaner smh tell hes mexican
# 2      0  youre fucking gay blacklisted hoe holding tehg...
# 3      0  lmfaoooo hate black people theres black people...
# 4      0                              least im nigger lmfao

# %% [markdown]
# ## Split Data

# %%
features = df['tweet']
target = df['class']

X_train, X_val, Y_train, Y_val = train_test_split(features,
												target,
												test_size=0.2,
												random_state=22)
X_train.shape, X_val.shape

# make labels categorical
Y_train = to_categorical(Y_train, num_classes=3)
Y_val = to_categorical(Y_val, num_classes=3)

# %% [markdown]
# ## Tokenization

# %%
with open('tokenizer.pkl', 'rb') as handle:
    token = pickle.load(handle)

# %%
# generating token embeddings
max_words = 5000
max_len = 100

X_train_seq = token.texts_to_sequences(X_train)
X_val_seq = token.texts_to_sequences(X_val)

X_train_padded = pad_sequences(X_train_seq, maxlen=max_len)
X_val_padded = pad_sequences(X_val_seq, maxlen=max_len)

# %% [markdown]
# ## Model

# %%
model = keras.models.Sequential([
	layers.Embedding(max_words, 32, input_length=max_len),

	# stacking LSTM and GRU
	layers.Bidirectional(layers.LSTM(16, return_sequences=True)),
	layers.Bidirectional(layers.GRU(16)),

	layers.Dense(512, activation='relu', kernel_regularizer='l1'),
	layers.BatchNormalization(),
	layers.Dropout(0.3),
	layers.Dense(3, activation='softmax')
])

model.compile(loss='categorical_crossentropy',
			optimizer='adam',
			metrics=['accuracy'])

model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ ?                           │     0 (unbuilt) │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# add a dummy input to build the model
model.build((None, max_len))

keras.utils.plot_model(
    model,
    show_shapes=True,
    show_dtype=True,
    show_layer_activations=True
)

# %%
lr = ReduceLROnPlateau(patience = 2,
					monitor = 'val_loss',
					factor = 0.5,
					verbose = 0)

# %%
# custom callback to calculate precision, recall, and F1-score
class MetricsCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs=None):
        val_predictions = np.argmax(self.model.predict(X_val_padded), axis=1)
        val_true = np.argmax(Y_val, axis=1)

        precision = precision_score(val_true, val_predictions, average='weighted')
        recall = recall_score(val_true, val_predictions, average='weighted')
        f1 = f1_score(val_true, val_predictions, average='weighted')

        print(f" - val_precision: {precision:.4f} - val_recall: {recall:.4f} - val_f1_score: {f1:.4f}")
        logs.update({'val_precision': precision, 'val_recall': recall, 'val_f1_score': f1})

# %%
metrics_callback = MetricsCallback()

history = model.fit(X_train_padded, Y_train,
					validation_data=(X_val_padded, Y_val),
					epochs=50,
					verbose=1,
					batch_size=32,
					callbacks=[lr, metrics_callback])
# Out:
# Epoch 1/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step
#  - val_precision: 0.8207 - val_recall: 0.8013 - val_f1_score: 0.8046
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 72s 205ms/step - accuracy: 0.6629 - loss: 3.8187 - val_accuracy: 0.8013 - val_loss: 0.9197 - learning_rate: 0.0010 - val_precision: 0.8207 - val_recall: 0.8013 - val_f1_score: 0.8046
# Epoch 2/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step
#  - val_precision: 0.8371 - val_recall: 0.8013 - val_f1_score: 0.8060
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 72s 172ms/step - accuracy: 0.8979 - loss: 0.3712 - val_accuracy: 0.8013 - val_loss: 0.5900 - learning_rate: 0.0010 - val_precision: 0.8371 - val_recall: 0.8013 - val_f1_score: 0.8060
# Epoch 3/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8564 - val_recall: 0.8440 - val_f1_score: 0.8396
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 86s 185ms/step - accuracy: 0.9344 - loss: 0.2787 - val_accuracy: 0.8440 - val_loss: 0.4911 - learning_rate: 0.0010 - val_precision: 0.8564 - val_recall: 0.8440 - val_f1_score: 0.8396
# Epoch 4/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step
#  - val_precision: 0.8585 - val_recall: 0.8519 - val_f1_score: 0.8500
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 78s 172ms/step - accuracy: 0.9532 - loss: 0.2033 - val_accuracy: 0.8519 - val_loss: 0.6274 - learning_rate: 0.0010 - val_precision: 0.8585 - val_recall: 0.8519 - val_f1_score: 0.8500
# Epoch 5/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8660 - val_recall: 0.8620 - val_f1_score: 0.8631
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 84s 180ms/step - accuracy: 0.9677 - loss: 0.1675 - val_accuracy: 0.8620 - val_loss: 0.5209 - learning_rate: 0.0010 - val_precision: 0.8660 - val_recall: 0.8620 - val_f1_score: 0.8631
# Epoch 6/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8808 - val_recall: 0.8775 - val_f1_score: 0.8762
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 87s 197ms/step - accuracy: 0.9755 - loss: 0.1192 - val_accuracy: 0.8775 - val_loss: 0.4871 - learning_rate: 5.0000e-04 - val_precision: 0.8808 - val_recall: 0.8775 - val_f1_score: 0.8762
# Epoch 7/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8629 - val_recall: 0.8549 - val_f1_score: 0.8514
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 191ms/step - accuracy: 0.9859 - loss: 0.0797 - val_accuracy: 0.8549 - val_loss: 0.6023 - learning_rate: 5.0000e-04 - val_precision: 0.8629 - val_recall: 0.8549 - val_f1_score: 0.8514
# Epoch 8/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8781 - val_recall: 0.8749 - val_f1_score: 0.8729
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 76s 172ms/step - accuracy: 0.9818 - loss: 0.0916 - val_accuracy: 0.8749 - val_loss: 0.5504 - learning_rate: 5.0000e-04 - val_precision: 0.8781 - val_recall: 0.8749 - val_f1_score: 0.8729
# Epoch 9/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8819 - val_recall: 0.8791 - val_f1_score: 0.8772
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 176ms/step - accuracy: 0.9893 - loss: 0.0633 - val_accuracy: 0.8791 - val_loss: 0.5264 - learning_rate: 2.5000e-04 - val_precision: 0.8819 - val_recall: 0.8791 - val_f1_score: 0.8772
# Epoch 10/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8861 - val_recall: 0.8841 - val_f1_score: 0.8822
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 81s 172ms/step - accuracy: 0.9887 - loss: 0.0597 - val_accuracy: 0.8841 - val_loss: 0.5717 - learning_rate: 2.5000e-04 - val_precision: 0.8861 - val_recall: 0.8841 - val_f1_score: 0.8822
# Epoch 11/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step
#  - val_precision: 0.8834 - val_recall: 0.8812 - val_f1_score: 0.8794
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 86s 186ms/step - accuracy: 0.9916 - loss: 0.0524 - val_accuracy: 0.8812 - val_loss: 0.5461 - learning_rate: 1.2500e-04 - val_precision: 0.8834 - val_recall: 0.8812 - val_f1_score: 0.8794
# Epoch 12/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8851 - val_recall: 0.8837 - val_f1_score: 0.8819
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 51s 169ms/step - accuracy: 0.9925 - loss: 0.0473 - val_accuracy: 0.8837 - val_loss: 0.5235 - learning_rate: 1.2500e-04 - val_precision: 0.8851 - val_recall: 0.8837 - val_f1_score: 0.8819
# Epoch 13/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8808 - val_recall: 0.8787 - val_f1_score: 0.8769
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 87s 187ms/step - accuracy: 0.9930 - loss: 0.0430 - val_accuracy: 0.8787 - val_loss: 0.5608 - learning_rate: 6.2500e-05 - val_precision: 0.8808 - val_recall: 0.8787 - val_f1_score: 0.8769
# Epoch 14/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step
#  - val_precision: 0.8840 - val_recall: 0.8825 - val_f1_score: 0.8806
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 53s 179ms/step - accuracy: 0.9924 - loss: 0.0429 - val_accuracy: 0.8825 - val_loss: 0.5578 - learning_rate: 6.2500e-05 - val_precision: 0.8840 - val_recall: 0.8825 - val_f1_score: 0.8806
# Epoch 15/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8834 - val_recall: 0.8808 - val_f1_score: 0.8787
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 181ms/step - accuracy: 0.9921 - loss: 0.0436 - val_accuracy: 0.8808 - val_loss: 0.5790 - learning_rate: 3.1250e-05 - val_precision: 0.8834 - val_recall: 0.8808 - val_f1_score: 0.8787
# Epoch 16/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8851 - val_recall: 0.8829 - val_f1_score: 0.8809
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 57s 190ms/step - accuracy: 0.9936 - loss: 0.0382 - val_accuracy: 0.8829 - val_loss: 0.5695 - learning_rate: 3.1250e-05 - val_precision: 0.8851 - val_recall: 0.8829 - val_f1_score: 0.8809
# Epoch 17/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step
#  - val_precision: 0.8835 - val_recall: 0.8816 - val_f1_score: 0.8797
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 81s 187ms/step - accuracy: 0.9939 - loss: 0.0373 - val_accuracy: 0.8816 - val_loss: 0.5677 - learning_rate: 1.5625e-05 - val_precision: 0.8835 - val_recall: 0.8816 - val_f1_score: 0.8797
# Epoch 18/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
#  - val_precision: 0.8834 - val_recall: 0.8816 - val_f1_score: 0.8797
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 191ms/step - accuracy: 0.9944 - loss: 0.0364 - val_accuracy: 0.8816 - val_loss: 0.5732 - learning_rate: 1.5625e-05 - val_precision: 0.8834 - val_recall: 0.8816 - val_f1_score: 0.8797
# Epoch 19/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step
#  - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 78s 180ms/step - accuracy: 0.9958 - loss: 0.0338 - val_accuracy: 0.8804 - val_loss: 0.5783 - learning_rate: 7.8125e-06 - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 20/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8842 - val_recall: 0.8825 - val_f1_score: 0.8805
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 84s 185ms/step - accuracy: 0.9931 - loss: 0.0383 - val_accuracy: 0.8825 - val_loss: 0.5767 - learning_rate: 7.8125e-06 - val_precision: 0.8842 - val_recall: 0.8825 - val_f1_score: 0.8805
# Epoch 21/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step
#  - val_precision: 0.8829 - val_recall: 0.8808 - val_f1_score: 0.8789
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 51s 172ms/step - accuracy: 0.9956 - loss: 0.0331 - val_accuracy: 0.8808 - val_loss: 0.5780 - learning_rate: 3.9063e-06 - val_precision: 0.8829 - val_recall: 0.8808 - val_f1_score: 0.8789
# Epoch 22/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 85s 181ms/step - accuracy: 0.9943 - loss: 0.0364 - val_accuracy: 0.8804 - val_loss: 0.5808 - learning_rate: 3.9063e-06 - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 23/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 173ms/step - accuracy: 0.9939 - loss: 0.0352 - val_accuracy: 0.8804 - val_loss: 0.5819 - learning_rate: 1.9531e-06 - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 24/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 176ms/step - accuracy: 0.9943 - loss: 0.0346 - val_accuracy: 0.8804 - val_loss: 0.5855 - learning_rate: 1.9531e-06 - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 25/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 82s 175ms/step - accuracy: 0.9943 - loss: 0.0331 - val_accuracy: 0.8812 - val_loss: 0.5801 - learning_rate: 9.7656e-07 - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 26/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8833 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 81s 171ms/step - accuracy: 0.9950 - loss: 0.0311 - val_accuracy: 0.8812 - val_loss: 0.5827 - learning_rate: 9.7656e-07 - val_precision: 0.8833 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 27/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 55s 185ms/step - accuracy: 0.9939 - loss: 0.0332 - val_accuracy: 0.8808 - val_loss: 0.5814 - learning_rate: 4.8828e-07 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 28/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
#  - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 79s 176ms/step - accuracy: 0.9940 - loss: 0.0351 - val_accuracy: 0.8804 - val_loss: 0.5820 - learning_rate: 4.8828e-07 - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 29/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 85s 187ms/step - accuracy: 0.9935 - loss: 0.0383 - val_accuracy: 0.8812 - val_loss: 0.5789 - learning_rate: 2.4414e-07 - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 30/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 180ms/step - accuracy: 0.9941 - loss: 0.0336 - val_accuracy: 0.8812 - val_loss: 0.5805 - learning_rate: 2.4414e-07 - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 31/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8836 - val_recall: 0.8816 - val_f1_score: 0.8796
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 185ms/step - accuracy: 0.9938 - loss: 0.0378 - val_accuracy: 0.8816 - val_loss: 0.5818 - learning_rate: 1.2207e-07 - val_precision: 0.8836 - val_recall: 0.8816 - val_f1_score: 0.8796
# Epoch 32/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 178ms/step - accuracy: 0.9937 - loss: 0.0361 - val_accuracy: 0.8812 - val_loss: 0.5812 - learning_rate: 1.2207e-07 - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 33/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 183ms/step - accuracy: 0.9939 - loss: 0.0375 - val_accuracy: 0.8808 - val_loss: 0.5807 - learning_rate: 6.1035e-08 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 34/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
#  - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 54s 182ms/step - accuracy: 0.9939 - loss: 0.0332 - val_accuracy: 0.8804 - val_loss: 0.5850 - learning_rate: 6.1035e-08 - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 35/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 177ms/step - accuracy: 0.9932 - loss: 0.0389 - val_accuracy: 0.8808 - val_loss: 0.5833 - learning_rate: 3.0518e-08 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 36/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 82s 178ms/step - accuracy: 0.9936 - loss: 0.0357 - val_accuracy: 0.8804 - val_loss: 0.5838 - learning_rate: 3.0518e-08 - val_precision: 0.8825 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 37/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8829 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 81s 175ms/step - accuracy: 0.9926 - loss: 0.0384 - val_accuracy: 0.8808 - val_loss: 0.5856 - learning_rate: 1.5259e-08 - val_precision: 0.8829 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 38/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 178ms/step - accuracy: 0.9918 - loss: 0.0388 - val_accuracy: 0.8812 - val_loss: 0.5802 - learning_rate: 1.5259e-08 - val_precision: 0.8832 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 39/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 82s 177ms/step - accuracy: 0.9935 - loss: 0.0355 - val_accuracy: 0.8804 - val_loss: 0.5793 - learning_rate: 7.6294e-09 - val_precision: 0.8824 - val_recall: 0.8804 - val_f1_score: 0.8784
# Epoch 40/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8839 - val_recall: 0.8821 - val_f1_score: 0.8801
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 85s 186ms/step - accuracy: 0.9946 - loss: 0.0318 - val_accuracy: 0.8821 - val_loss: 0.5779 - learning_rate: 7.6294e-09 - val_precision: 0.8839 - val_recall: 0.8821 - val_f1_score: 0.8801
# Epoch 41/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 54s 179ms/step - accuracy: 0.9937 - loss: 0.0360 - val_accuracy: 0.8812 - val_loss: 0.5777 - learning_rate: 3.8147e-09 - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 42/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 54s 181ms/step - accuracy: 0.9921 - loss: 0.0393 - val_accuracy: 0.8808 - val_loss: 0.5821 - learning_rate: 3.8147e-09 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 43/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step
#  - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 183ms/step - accuracy: 0.9939 - loss: 0.0357 - val_accuracy: 0.8812 - val_loss: 0.5803 - learning_rate: 1.9073e-09 - val_precision: 0.8831 - val_recall: 0.8812 - val_f1_score: 0.8792
# Epoch 44/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 82s 185ms/step - accuracy: 0.9941 - loss: 0.0380 - val_accuracy: 0.8808 - val_loss: 0.5833 - learning_rate: 1.9073e-09 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 45/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8842 - val_recall: 0.8825 - val_f1_score: 0.8805
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 101s 248ms/step - accuracy: 0.9927 - loss: 0.0369 - val_accuracy: 0.8825 - val_loss: 0.5738 - learning_rate: 9.5367e-10 - val_precision: 0.8842 - val_recall: 0.8825 - val_f1_score: 0.8805
# Epoch 46/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step
#  - val_precision: 0.8836 - val_recall: 0.8816 - val_f1_score: 0.8796
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 53s 179ms/step - accuracy: 0.9925 - loss: 0.0363 - val_accuracy: 0.8816 - val_loss: 0.5822 - learning_rate: 9.5367e-10 - val_precision: 0.8836 - val_recall: 0.8816 - val_f1_score: 0.8796
# Epoch 47/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 83s 184ms/step - accuracy: 0.9931 - loss: 0.0373 - val_accuracy: 0.8808 - val_loss: 0.5788 - learning_rate: 4.7684e-10 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 48/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 80s 175ms/step - accuracy: 0.9917 - loss: 0.0431 - val_accuracy: 0.8808 - val_loss: 0.5824 - learning_rate: 4.7684e-10 - val_precision: 0.8828 - val_recall: 0.8808 - val_f1_score: 0.8788
# Epoch 49/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step
#  - val_precision: 0.8844 - val_recall: 0.8825 - val_f1_score: 0.8805
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 84s 183ms/step - accuracy: 0.9935 - loss: 0.0362 - val_accuracy: 0.8825 - val_loss: 0.5819 - learning_rate: 2.3842e-10 - val_precision: 0.8844 - val_recall: 0.8825 - val_f1_score: 0.8805
# Epoch 50/50
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
#  - val_precision: 0.8839 - val_recall: 0.8821 - val_f1_score: 0.8801
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 82s 184ms/step - accuracy: 0.9946 - loss: 0.0334 - val_accuracy: 0.8821 - val_loss: 0.5787 - learning_rate: 2.3842e-10 - val_precision: 0.8839 - val_recall: 0.8821 - val_f1_score: 0.8801

# %% [markdown]
# ## Visualize Model Results

# %%
history_df = pd.DataFrame(history.history)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# plot loss
history_df.loc[:, ['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('Training and Validation Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend(['Training Loss', 'Validation Loss'])

# plot accuracy
history_df.loc[:, ['accuracy', 'val_accuracy']].plot(ax=axes[1])
axes[1].set_title('Training and Validation Accuracy')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Accuracy')
axes[1].legend(['Training Accuracy', 'Validation Accuracy'])

plt.tight_layout()
plt.show()

# %%
pred = model.predict(X_val_padded)
pred_class = np.argmax(pred, axis=1)

# plot the confusion matrix
Y_val_class = np.argmax(Y_val, axis=1)
conf_matrix = confusion_matrix(Y_val_class, pred_class)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Hate Speech', 'Offensive Language', 'No Hate and Offensive'],
            yticklabels=['Hate Speech', 'Offensive Language', 'No Hate and Offensive'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step

# %%
print("Classification Report:\n")
print(classification_report(Y_val_class, pred_class))
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91       900
#            1       0.91      0.76      0.83       691
#            2       0.89      0.89      0.89       800
#
#     accuracy                           0.88      2391
#    macro avg       0.89      0.87      0.88      2391
# weighted avg       0.88      0.88      0.88      2391

# %%
# look at the misclassified tweets

pred_df = pd.DataFrame(pred_class, columns=['pred_class'])
pred_df['actual_class'] = np.argmax(Y_val, axis=1)
pred_df['tweet'] = X_val.values

misclassified_tweets = pred_df[pred_df['pred_class'] != pred_df['actual_class']]
misclassified_tweets.head()
# Out:
#     pred_class  actual_class  \
# 10           1             2
# 11           0             1
# 44           1             2
# 60           2             0
# 71           2             1
#
#                                                 tweet
# 10  nobody judging birds account wouldnt even caus...
# 11                                 release nudes cunt
# 44                                   tweets trash8221
# 60                                  washing coon hair
# 71      never trust nicca volunteers another man info

# %% [markdown]
# ## Save Model

# %%
model.save('rnn_w_GRU_and_LSTM.keras')
